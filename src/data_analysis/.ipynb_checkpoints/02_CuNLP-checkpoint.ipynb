# %%
import pandas as pd

# %%
df = pd.read_csv("../../data/original/Cu-NLP/CU-NLP.csv", sep=";", encoding="cp857")

# %%
df.head(10)
# Out:
#    no                                          question1  \
# 0   0  If the question is IR-Based, I will do the fol...
# 1   1  If the question is IR-Based, I will do the fol...
# 2   2  If the question is IR-Based, I will do the fol...
# 3   3  If the question is IR-Based, I will do the fol...
# 4   4  If the question is IR-Based, I will do the fol...
# 5   5  If the question is IR-Based, I will do the fol...
# 6   6  If the question is IR-Based, I will do the fol...
# 7   7  If the question is IR-Based, I will do the fol...
# 8   8  If the question is IR-Based, I will do the fol...
# 9   9  If the question is Knowledge-Based, I will do ...
#
#                                            question2  grade
# 0  Using semantic analysis methods. We can use ve...     25
# 1  we should use vector space model. firstly, bin...     25
# 2  Assume we have a question like " Why the sky i...     50
# 3  We can use Vector Space Model that is represen...     25
# ...

# %%
df.describe()
# Out:
#                no       grade
# count  171.000000  171.000000
# mean    85.000000   27.953216
# std     49.507575   24.486926
# min      0.000000    0.000000
# 25%     42.500000   10.000000
# 50%     85.000000   25.000000
# 75%    127.500000   45.000000
# max    170.000000  100.000000

# %%
df.nunique()
# Out:
# no           171
# question1      5
# question2    171
# grade          9
# dtype: int64
