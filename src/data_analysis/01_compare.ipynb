# %% [markdown]
# # Comparing and combining the data sets

# %%
import pandas as pd

from combine import combine_datasets, normalize_grade, load_datasets
import altair as alt
vega_fusion = alt.data_transformers.enable("vegafusion")

# %% [markdown]
# ## Combining the datasets

# %%
datasets = load_datasets()
datasets = list(map(normalize_grade, datasets))

df_combined = combine_datasets(datasets)
df_combined.drop(columns=[
    "reference_answer1",
    "reference_answer2",
    "file_name",
    "accuracy",
    "assignment",
    "student_id",    
],inplace=True)
df_combined.head()
# Out:
#                                         question  \
# 0  Explain why circuit 4 is not a short circuit.
# 1  Explain why circuit 4 is not a short circuit.
# 2  Explain why circuit 4 is not a short circuit.
# 3  Explain why circuit 4 is not a short circuit.
# 4  Explain why circuit 4 is not a short circuit.
#
#                                   provided_answer  \
# 0   the battery is not contained in a closed path
# 1  the battery is  not contained in a closed path
# 2             Because it is in an incomplete path
# 3                         The path does not close
# 4            The battery is not in a closed path.
#
#                 reference_answer  grade data_source  normalized_grade   id  \
# 0  Circuit 4 has no closed paths    3.0      Beetle          1.000000  NaN
# 1  Circuit 4 has no closed paths    3.0      Beetle          1.000000  NaN
# 2  Circuit 4 has no closed paths    1.0      Beetle          0.333333  NaN
# 3  Circuit 4 has no closed paths    3.0      Beetle          1.000000  NaN
# 4  Circuit 4 has no closed paths    3.0      Beetle          1.000000  NaN
#
#   answer_feedback verification_feedback split
# 0             NaN                   NaN   NaN
# 1             NaN                   NaN   NaN
# 2             NaN                   NaN   NaN
# 3             NaN                   NaN   NaN
# 4             NaN                   NaN   NaN

# %%
df_combined['data_source'] = pd.Categorical(df_combined.data_source)

alt.Chart(df_combined).mark_bar().encode(
    alt.X("data_source"),
    y='count()',
)
# Out:
# alt.Chart(...)

# %% [markdown]
# To verify that the normalizing is actually working as intended, we can compare the original distribution of a single data set with the normalized distribution.

# %%
filtered_df = df_combined.loc[df_combined['data_source'] == "CU-NLP"]

# %%
alt.Chart(filtered_df).mark_bar().encode(
    alt.X("grade").bin(),
    y='count()',
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(filtered_df).mark_bar().encode(
    alt.X("normalized_grade").bin(),
    y='count()',
)
# Out:
# alt.Chart(...)

# %% [markdown]
# That seems to be working well!
# Then we can have a look at the distributions over all the data:

# %%
alt.Chart(df_combined).mark_bar().encode(
    alt.X("normalized_grade").title("Grade on a scale from 0 to 1").bin(),
    alt.Y('count()').title("Number of Records"),
    color=alt.Color('data_source:N').title("Data Source"),
).properties(
    width=500,
    height=300
)
# Out:
# alt.Chart(...)

# %%
df_combined.describe()
# Out:
#              grade  normalized_grade
# count  7723.000000       7723.000000
# mean      2.370238          0.526783
# std       5.432110          0.342645
# min       0.000000          0.000000
# 25%       1.000000          0.285714
# 50%       1.000000          0.333333
# 75%       3.000000          1.000000
# max     100.000000          1.000000

# %%
df_combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7723 entries, 0 to 170
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   question               7552 non-null   object
#  1   provided_answer        7723 non-null   object
#  2   reference_answer       7723 non-null   object
#  3   grade                  7723 non-null   float64
#  4   data_source            7723 non-null   category
#  5   normalized_grade       7723 non-null   float64
#  6   id                     2981 non-null   object
#  7   answer_feedback        2981 non-null   object
#  8   verification_feedback  2981 non-null   object
#  9   split                  2981 non-null   object
# dtypes: category(1), float64(2), object(7)
# memory usage: 611.1+ KB

# %%
check_missing = df_combined.loc[pd.isnull(df_combined['question'])]
check_missing.head()
# Out:
#   question                                    provided_answer  \
# 0      NaN  If the question is IR-Based, I will do the fol...
# 1      NaN  If the question is IR-Based, I will do the fol...
# 2      NaN  If the question is IR-Based, I will do the fol...
# 3      NaN  If the question is IR-Based, I will do the fol...
# 4      NaN  If the question is IR-Based, I will do the fol...
#
#                                     reference_answer  grade data_source  \
# 0  Using semantic analysis methods. We can use ve...   25.0      CU-NLP
# 1  we should use vector space model. firstly, bin...   25.0      CU-NLP
# 2  Assume we have a question like " Why the sky i...   50.0      CU-NLP
# 3  We can use Vector Space Model that is represen...   25.0      CU-NLP
# 4  In this corpus we will use sentence segmenting...   50.0      CU-NLP
#
#    normalized_grade   id answer_feedback verification_feedback split
# 0              0.25  NaN             NaN                   NaN   NaN
# 1              0.25  NaN             NaN                   NaN   NaN
# 2              0.50  NaN             NaN                   NaN   NaN
# 3              0.25  NaN             NaN                   NaN   NaN
# 4              0.50  NaN             NaN                   NaN   NaN
